# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine  = create_engine(f"postgresql://postgres:Abdulaziz1993@localhost:5432/dvdrental")

# %%
tables = pd.read_sql_query("""SELECT table_name FROM INFORMATION_SCHEMA.TABLES
WHERE is_insertable_into = 'YES' AND table_schema = 'public';""", engine)['table_name']

# %%
for table in tables.values:
    query = f"SELECT column_name, data_type FROM INFORMATION_SCHEMA.COLUMNS WHERE table_name = {table};"
    pd.read_sql_query(query, engine)
    print(query)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1904                 if not evt_handled:
# -> 1905                     self.dialect.do_execute(
#    1906                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     735     def do_execute(self, cursor, statement, parameters, context=None):
# --> 736         cursor.execute(statement, parameters)
#     737
#
# UndefinedColumn: column "customer" does not exist
# LINE 1: ...FROM INFORMATION_SCHEMA.COLUMNS WHERE table_name = customer;
#                                                               ^
#
#
# ...

# %%
def getSqlQuery(query):
    return pd.read_sql_query(query, engine)

# %%
# getting all sql tables
actor = getSqlQuery('SELECT * FROM actor;')
address = getSqlQuery('SELECT * FROM address;')
category = getSqlQuery('SELECT * FROM category;')
city = getSqlQuery('SELECT * FROM city;')
country = getSqlQuery('SELECT * FROM country;')
customer = getSqlQuery('SELECT * FROM customer;')
film = getSqlQuery('SELECT * FROM film;')
film_actor = getSqlQuery('SELECT * FROM film_actor;')
film_category = getSqlQuery('SELECT * FROM film_category;')
inventory = getSqlQuery('SELECT * FROM inventory;')
language = getSqlQuery('SELECT * FROM language;')
payment = getSqlQuery('SELECT * FROM payment;')
rental = getSqlQuery('SELECT * FROM rental;')
staff = getSqlQuery('SELECT * FROM staff;')
store = getSqlQuery('SELECT * FROM store;')

## This code will do the exact same thing:
# for table in tables.values:
    # exec(f"{table} = getSqlQuery(f'SELECT * FROM {table}')")


## or as a dictionary:
#dictOfTables = {}
#for table in tables.values:
    #dictOfTables[table] = getSqlQuery(f'SELECT * FROM {table}')

# %%
# film_dim
film_dim = pd.DataFrame()
film_dim['film_id'] = film['film_id']
film_dim['title'] = film['title']
film_dim['description'] = film['description']
film_dim['release_year'] = film['release_year']
film_dim['language_id'] = film['language_id']
film_dim['rental_duration'] = film['rental_duration']
film_dim['rental_rate'] = film['rental_rate']
film_dim['length'] = film['length']
film_dim['replacement_cost'] = film['replacement_cost']
film_dim['rating'] = film['rating']
film_dim['last_update'] = film['last_update']
film_dim['special_features'] = film['special_features']
film_dim['fulltext'] = film['fulltext']
film_dim['category_id'] = pd.merge(film_dim, film_category, on='film_id')['category_id']
film_dim['film_last_update'] = film['last_update']
film_dim['category_name'] = pd.merge(film_dim, category, on='category_id', how='left')['name']

# film_dim[''] = film['']
# film_dim[''] = film['']
# film_dim[''] = film['']
# film_dim[''] = film['']
# film_dim[''] = film['']
# film_dim[''] = film['']
# film_dim[''] = film['']
# film_dim[''] = film['']
# film_dim[''] = film['']
# film_dim[''] = film['']

# film_dim[film_dim.isna().any(axis=1)]

film_dim.head(40)
# Out:
#    film_id              title  \
# 0      133    Chamber Italian
# 1      384   Grosse Wonderful
# 2        8    Airport Pollock
# 3       98  Bright Encounters
# 4        1   Academy Dinosaur
# 5        2     Ace Goldfinger
# 6        3   Adaptation Holes
# 7        4   Affair Prejudice
# 8        5        African Egg
# 9        6       Agent Truman
#
#                                          description  release_year  \
# 0  A Fateful Reflection of a Moose And a Husband ...          2006
# 1  A Epic Drama of a Cat And a Explorer who must ...          2006
# 2  A Epic Tale of a Moose And a Girl who must Con...          2006
# 3  A Fateful Yarn of a Lumberjack And a Feminist ...          2006
# 4  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 5  A Astounding Epistle of a Database Administrat...          2006
# 6  A Astounding Reflection of a Lumberjack And a ...          2006
# 7  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# ...

# %%
mergedData = pd.merge(film_dim, category, on='category_id')
mergedData[mergedData['category_name'] != mergedData['name']]
# Out:
#      film_id             title  \
# 5         51  Balloon Homeward
# 6         54  Banger Pinocchio
# 7         74   Birch Antitrust
# 8         76   Birdcage Casper
# 9         86     Boogie Amelie
# ..       ...               ...
# 991      883      Tequila Past
# 992      889       Ties Hunger
# 993      896     Tootsie Pilot
# 994      918   Twisted Pirates
# 995      928      Uptown Young
#
#                                            description  release_year  \
# 5    A Insightful Panorama of a Forensic Psychologi...          2006
# 6    A Awe-Inspiring Drama of a Car And a Pastry Ch...          2006
# 7    A Fanciful Panorama of a Husband And a Pioneer...          2006
# 8    A Fast-Paced Saga of a Frisbee And a Astronaut...          2006
# 9    A Lacklusture Character Study of a Husband And...          2006
# ..                                                 ...           ...
# 991  A Action-Packed Panorama of a Mad Scientist An...          2006
# ...

# %%
mergedData[mergedData['category_name'] != mergedData['name']]

# %%
film_dim['category_id'].replace(category['name'])
# Out:
# 0              New
# 1              New
# 2            Music
# 3           Family
# 4            Drama
#           ...
# 995          Drama
# 996            New
# 997          Music
# 998       Classics
# 999    Documentary
# Name: category_id, Length: 1000, dtype: object

# %%
category
# Out:
#     category_id         name         last_update
# 0             1       Action 2006-02-15 09:46:27
# 1             2    Animation 2006-02-15 09:46:27
# 2             3     Children 2006-02-15 09:46:27
# 3             4     Classics 2006-02-15 09:46:27
# 4             5       Comedy 2006-02-15 09:46:27
# 5             6  Documentary 2006-02-15 09:46:27
# 6             7        Drama 2006-02-15 09:46:27
# 7             8       Family 2006-02-15 09:46:27
# 8             9      Foreign 2006-02-15 09:46:27
# 9            10        Games 2006-02-15 09:46:27
# 10           11       Horror 2006-02-15 09:46:27
# 11           12        Music 2006-02-15 09:46:27
# 12           13          New 2006-02-15 09:46:27
# 13           14       Sci-Fi 2006-02-15 09:46:27
# 14           15       Sports 2006-02-15 09:46:27
# 15           16       Travel 2006-02-15 09:46:27
